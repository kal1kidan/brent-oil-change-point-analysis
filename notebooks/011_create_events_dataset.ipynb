# %%
import pandas as pd

# Create the events data
events_data = {
    "Date": [
        "2001-09-11", "2003-03-20", "2005-08-29", "2008-09-15", 
        "2010-04-20", "2011-03-11", "2014-11-27", "2016-11-30", 
        "2020-03-11", "2020-04-20", "2022-02-24", "2022-03-08", "2022-06-02"
    ],
    "Event Description": [
        "9/11 Terrorist attacks affect global oil demand",
        "Iraq War begins",
        "Hurricane Katrina damages US oil production",
        "Lehman Brothers collapse, financial crisis",
        "Deepwater Horizon oil spill in Gulf of Mexico",
        "Japan earthquake and tsunami disrupt energy supply",
        "OPEC decides not to cut production",
        "OPEC and non-OPEC agreement to cut output",
        "COVID-19 declared a global pandemic",
        "WTI crude futures go negative for first time",
        "Russia-Ukraine war begins",
        "Sanctions on Russian oil exports announced",
        "OPEC+ agrees on production cut"
    ],
    "Category": [
        "Economic Shock", "Conflict", "Other", "Economic Shock",
        "Other", "Other", "OPEC", "OPEC",
        "Economic Shock", "Economic Shock", "Conflict", "Economic Shock", "OPEC"
    ]
}

# Create DataFrame
events_df = pd.DataFrame(events_data)

# Save to CSV
events_df.to_csv(r"C:\Users\bezis\Downloads\brent-oil-change-point\data\events.csv", index=False)


print("events.csv created successfully!")
# Out:
# events.csv created successfully!

# %%
events_df
# Out:
#           Date                                  Event Description  \
# 0   2001-09-11    9/11 Terrorist attacks affect global oil demand
# 1   2003-03-20                                    Iraq War begins
# 2   2005-08-29        Hurricane Katrina damages US oil production
# 3   2008-09-15         Lehman Brothers collapse, financial crisis
# 4   2010-04-20      Deepwater Horizon oil spill in Gulf of Mexico
# 5   2011-03-11  Japan earthquake and tsunami disrupt energy su...
# 6   2014-11-27                 OPEC decides not to cut production
# 7   2016-11-30          OPEC and non-OPEC agreement to cut output
# 8   2020-03-11                COVID-19 declared a global pandemic
# 9   2020-04-20       WTI crude futures go negative for first time
# 10  2022-02-24                          Russia-Ukraine war begins
# 11  2022-03-08         Sanctions on Russian oil exports announced
# 12  2022-06-02                     OPEC+ agrees on production cut
#
#           Category
# 0   Economic Shock
# ...
